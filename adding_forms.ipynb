# %% [markdown]
# Here we will connect 2 types of dfs:
# 1. The matches db that includes the __names__ of the players
# 2. The player ratings db that inclueds also the __names__ of the players
#
# We will connect via the closest string for each player in a match in order to get:
# 1. player rating
# 2. player age
# 3. player height

# %%
import pandas as pd
import numpy as np
from difflib import SequenceMatcher
from bs4 import BeautifulSoup
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# First we need to fix the club name issue, for exmaple Man utd in the matches db is not the same as Manchester United

# %%
def add_form(processed_csv, standings_csv):

    season = pd.read_csv(processed_csv)
    standings = pd.read_csv(standings_csv)
    standings.set_index("Team", inplace=True)
    names_fix = {'Man Utd': "Manchester United",
             "Man City": 'Manchester City',
             "West Ham": "West Ham United",
             "Nott'm Forest": "Nottingham Forest",
             'Spurs': "Tottenham Hotspur",
             'Wolves': "Wolverhampton Wanderers",
             "Brighton & Hove Albion": "Brighton and Hove Albion",
             'Newcastle': 'Newcastle United',
             'Leicester': 'Leicester City',
             'Leeds': "Leeds United",
             'Huddersfield' : 'Huddersfield Town',
             'Swansea' : 'Swansea City',
             'Cardiff': 'Cardiff City',
             'Norwich' : 'Norwich City',
             'Stoke' : 'Stoke City',
             'West Brom' : 'West Bromwich Albion',
             'Hull' : 'Hull City',
             'QPR' : 'Queens Park Rangers',
             'Sheffield Utd' : 'Sheffield United',
             "AFC Bournemouth" :"Bournemouth"}
    columns = list(standings.columns)
    for index, row in season.iterrows():
        matchweek = row['Matchweek']

        if matchweek > 1:
            rank_col = columns[columns.index("Matchweek "+str(matchweek)+"_Rank")-3]
            points_col = columns[columns.index("Matchweek "+str(matchweek)+"_Rank")-2]
            # Get teams at specific ranks
            first_place_team = None
            fourth_place_team = None
            seventeenth_place_team = None
            
            for team, rank in standings[rank_col].items():
                if rank == 1:
                    first_place_team = team
                elif rank == 4:
                    fourth_place_team = team
                elif rank == 17:
                    seventeenth_place_team = team
            # print('first place:',first_place_team)
            # print('fourth:',fourth_place_team)
            # print('relegeated:',seventeenth_place_team)
                    
            home_points_prior = season.at[index, 'home_Points_prior'] if season.at[index, 'home_Points_prior'] else 0
            away_points_prior = season.at[index, 'away_Points_prior'] if season.at[index, 'away_Points_prior'] else 0
            first_place_points = standings.loc[first_place_team, points_col] if first_place_team else 0
            fourth_place_points = standings.loc[fourth_place_team, points_col] if fourth_place_team else 0
            seventeenth_place_points = standings.loc[seventeenth_place_team, points_col] if seventeenth_place_team else 0
            
            season.at[index, 'home_points_to_championship'] = first_place_points - home_points_prior/(38-matchweek+1)
            season.at[index, 'home_points_to_ucl'] = fourth_place_points - home_points_prior/(38-matchweek+1)
            season.at[index, 'home_points_to_rel'] = seventeenth_place_points - home_points_prior/(38-matchweek+1)

            season.at[index, 'away_points_to_championship'] = first_place_points - away_points_prior/(38-matchweek+1)
            season.at[index, 'away_points_to_ucl'] = fourth_place_points - away_points_prior/(38-matchweek+1)
            season.at[index, 'away_points_to_rel'] = seventeenth_place_points - away_points_prior/(38-matchweek+1)

        else:
            season.at[index, 'home_points_to_championship'] = 0
            season.at[index, 'home_points_to_ucl'] = 0
            season.at[index, 'home_points_to_rel'] = 0

            season.at[index, 'away_points_to_championship'] = 0
            season.at[index, 'away_points_to_ucl'] = 0
            season.at[index, 'away_points_to_rel'] = 0

        ## setting match importance:
            
        home_chances = np.array([season.at[index, 'home_points_to_championship'],
                                 season.at[index, 'home_points_to_ucl'],
                                 season.at[index, 'home_points_to_rel']])
        away_chances = np.array([season.at[index, 'away_points_to_championship'],
                                 season.at[index, 'away_points_to_ucl'],
                                 season.at[index, 'away_points_to_rel']])
        home_importances = np.abs(home_chances)
        away_importances = np.abs(away_chances)
        home_imp = home_chances[np.argmin(home_importances)]
        away_imp = away_chances[np.argmin(away_importances)]
        if abs(home_imp) > 3:
            home_imp = 0
        if abs(away_imp) > 3:
            away_imp = 0
        season.at[index, 'home_match_importance'] = home_imp
        season.at[index, 'away_match_importance'] = away_imp
        if columns.index("Matchweek "+str(matchweek)+"_Rank") < 17: #if we are in the first 5 matches
            season.at[index, 'home_GD_form'] = season.at[index, 'home_GD_prior']
            season.at[index, 'home_Points_form'] = season.at[index, 'home_GD_prior']
            season.at[index, 'home_GD_form_pw'] = season.at[index, 'home_GD_form'] / matchweek
            season.at[index, 'home_Points_form_pw'] = season.at[index, 'home_Points_form'] / matchweek

            season.at[index, 'away_Points_form'] = season.at[index, 'away_Points_prior']     
            season.at[index, 'away_GD_form'] = season.at[index, 'away_GD_prior']
            season.at[index, 'away_GD_form_pw'] = season.at[index, 'away_GD_form'] / matchweek
            season.at[index, 'away_Points_form_pw'] = season.at[index, 'away_Points_form'] / matchweek
            
            
            
        else:
            prior_gd_col = columns[columns.index("Matchweek "+str(matchweek)+"_GD")-18]
            prior_points_col = columns[columns.index("Matchweek "+str(matchweek)+"_Points")-18]
            home_team = season.at[index, 'home_team_name']
            away_team = season.at[index, 'away_team_name']

            if home_team in names_fix.keys():
                home_team = names_fix[home_team]
            if away_team in names_fix.keys():
                away_team = names_fix[away_team]
            #getting for home
            home_gd_prior = standings.at[home_team, prior_gd_col]
            home_points_prior = standings.at[home_team, prior_points_col]
            if(home_gd_prior == None or np.isnan(home_gd_prior)):
                home_gd_prior=0
            if(home_points_prior == None or np.isnan(home_points_prior)):
                home_points_prior = 0
            
            prior_gw = int(prior_gd_col[:len(prior_gd_col)-3].split()[1])
            #getting for away
            away_gd_prior = standings.at[away_team, prior_gd_col]
            away_points_prior = standings.at[away_team, prior_points_col]
            if away_gd_prior == None or np.isnan(away_gd_prior):
                away_gd_prior = 0
            if away_points_prior == None or np.isnan(away_points_prior):
                away_points_prior = 0


            season.at[index, 'home_GD_form'] = season.at[index, 'home_GD_prior'] - home_gd_prior
            season.at[index, 'home_Points_form'] = season.at[index, 'home_Points_prior'] - home_points_prior
            season.at[index, 'home_GD_form_pw'] = season.at[index, 'home_GD_form'] / (matchweek - prior_gw + 1)
            season.at[index, 'home_Points_form_pw'] = season.at[index, 'home_Points_form'] / (matchweek -prior_gw+1)
            season.at[index, 'away_GD_form'] = season.at[index, 'away_GD_prior'] - away_gd_prior
            season.at[index, 'away_Points_form'] = season.at[index, 'away_Points_prior'] - away_points_prior
            season.at[index, 'away_GD_form_pw'] = season.at[index, 'away_GD_form'] / (matchweek - prior_gw+1)
            season.at[index, 'away_Points_form_pw'] = season.at[index, 'away_Points_form'] / (matchweek -prior_gw+1)

    return season

# %%
def add_betting(df, season):
    betting = pd.read_csv("betting/"+season+"_betting.csv")
    # file_name = file_path.split('/')[-1]  # Extracts the file name from the path
    # epl_string = file_name.split('_')[0]

    names_fix = {'Man Utd': "Manchester United",
             'Man United' : "Manchester United",
             "Man City": 'Manchester City',
             "West Ham": "West Ham United",
             "Nott'm Forest": "Nottingham Forest",
             'Spurs': "Tottenham Hotspur",
             'Tottenham' : "Tottenham Hotspur",
             'Wolves': "Wolverhampton Wanderers",
             "Brighton and Hove Albion": "Brighton & Hove Albion",
              "Brighton": "Brighton & Hove Albion",  
             "Bournemouth": "AFC Bournemouth",
             'Newcastle': 'Newcastle United',
             'Leicester': 'Leicester City',
             'Leeds': "Leeds United",
             'Huddersfield' : 'Huddersfield Town',
             'Swansea' : 'Swansea City',
             'Cardiff': 'Cardiff City',
             'Norwich' : 'Norwich City',
             'Stoke' : 'Stoke City',
             'West Brom' : 'West Bromwich Albion',
             'Hull' : 'Hull City',
             'QPR' : 'Queens Park Rangers',
             'Sheffield Utd' : 'Sheffield United'}
    
    for key, val in names_fix.items():
        betting['HomeTeam'].replace(key, val, inplace=True)
        betting['AwayTeam'].replace(key, val, inplace=True)
    print('replaced all the names')
    for index, row in df.iterrows():
        # add the AvgA, AvgD, AvgH for home_team_name == HomeTeam and away_team_name === AwayTeam
        home_team_name = row['home_team_name']
        away_team_name = row['away_team_name']
        # Filter betting DataFrame to find corresponding rows
        if (not home_team_name in betting['HomeTeam'].values):
            print("Fix the names:",home_team_name)
        if (not away_team_name  in betting['AwayTeam'].values):
            print("Fix the names:",away_team_name)
        matching_row = betting[(betting['HomeTeam'] == home_team_name) & (betting['AwayTeam'] == away_team_name)]
        matching_row = matching_row.iloc[0]

        print(matching_row)
        df.at[index, 'B365A'] = matching_row['B365A']
        df.at[index, 'B365D'] = matching_row['B365D']
        df.at[index, 'B365H'] = matching_row['B365H']

# %%
df = add_form('processed Datasets/MatchDB/epl2223_proccessed.csv', 'standings/standings_epl2223.csv')

# %%
def add_forms_pipeline(seasons, standings_list):
    for i in range(len(seasons)):
        file_name = seasons[i].split('/')[-1]  # Extracts the file name from the path
        epl_string = file_name.split('_')[0]
        new_season = add_form (seasons[i], standings_list[i])
        add_betting(new_season, epl_string)
        new_name = seasons[i].split('.')[0]+'_with_form.csv'
        new_season.to_csv(new_name)

# %%
add_forms_pipeline(['processed Datasets/MatchDB/epl1516_proccessed.csv', 
                    'processed Datasets/MatchDB/epl2122_proccessed.csv',
          'processed Datasets/MatchDB/epl1819_proccessed.csv', 'processed Datasets/MatchDB/epl1617_proccessed.csv',
          'processed Datasets/MatchDB/epl1718_proccessed.csv', 'processed Datasets/MatchDB/epl1415_proccessed.csv',
            'processed Datasets/MatchDB/epl1920_proccessed.csv', 'processed Datasets/MatchDB/epl2021_proccessed.csv',
              'processed Datasets/MatchDB/epl2223_proccessed.csv'],
          ['standings/standings_epl1516.csv','standings/standings_epl2122.csv',
           'standings/standings_epl1819.csv','standings/standings_epl1617.csv',
           'standings/standings_epl1718.csv','standings/standings_epl1415.csv',
           'standings/standings_epl1920.csv','standings/standings_epl2021.csv',
           'standings/standings_epl2223.csv'])
# Out:
# replaced all the names
# Div                        E0
# Date               17/05/2016
# HomeTeam    Manchester United
# AwayTeam      AFC Bournemouth
# FTHG                        3
#                   ...
# BbMxAHA                  2.08
# BbAvAHA                  2.02
# PSCH                      1.5
# PSCD                      4.6
# PSCA                     7.03
# Name: 379, Length: 65, dtype: object
# Div                  E0
# Date         15/05/2016
# HomeTeam        Arsenal
# AwayTeam    Aston Villa
# FTHG                  4
#                ...
# BbMxAHA            1.99
# BbAvAHA            1.94
# PSCH               1.12
# PSCD              12.03
# PSCA               23.6
# Name: 370, Length: 65, dtype: object
# Div                     E0
# Date            15/05/2016
# HomeTeam           Chelsea
# AwayTeam    Leicester City
# FTHG                     1
#                  ...
# BbMxAHA               1.92
# BbAvAHA               1.87
# PSCH                  2.01
# PSCD                  3.99
# PSCA                  3.68
# Name: 371, Length: 65, dtype: object
# Div                   E0
# Date          15/05/2016
# HomeTeam         Everton
# AwayTeam    Norwich City
# FTHG                   3
#                 ...
# BbMxAHA              2.0
# BbAvAHA             1.93
# PSCH                1.74
# PSCD                4.38
# PSCA                 4.6
# Name: 372, Length: 65, dtype: object
# Div                        E0
# Date               15/05/2016
# HomeTeam     Newcastle United
# AwayTeam    Tottenham Hotspur
# FTHG                        5
#                   ...
# BbMxAHA                  2.01
# BbAvAHA                  1.97
# PSCH                      5.3
# PSCD                     4.18
# PSCA                     1.69
# Name: 373, Length: 65, dtype: object
# Div                     E0
# Date            15/05/2016
# HomeTeam       Southampton
# AwayTeam    Crystal Palace
# FTHG                     4
#                  ...
# BbMxAHA               1.98
# BbAvAHA               1.92
# PSCH                  1.29
# PSCD                   6.8
# PSCA                  10.0
# Name: 374, Length: 65, dtype: object
# Div                      E0
# Date             15/05/2016
# HomeTeam         Stoke City
# AwayTeam    West Ham United
# FTHG                      2
#                  ...
# BbMxAHA                1.87
# BbAvAHA                1.83
# PSCH                   3.05
# PSCD                    4.0
# PSCA                   2.26
# Name: 375, Length: 65, dtype: object
# Div                      E0
# Date             15/05/2016
# HomeTeam       Swansea City
# AwayTeam    Manchester City
# FTHG                      1
#                  ...
# BbMxAHA                1.85
# BbAvAHA                1.81
# PSCH                   7.05
# PSCD                    5.0
# PSCA                   1.47
# Name: 376, Length: 65, dtype: object
# Div                 E0
# Date        15/05/2016
# HomeTeam       Watford
# AwayTeam    Sunderland
# FTHG                 2
#                ...
# BbMxAHA           1.91
# BbAvAHA           1.85
# PSCH              1.64
# PSCD              4.52
# PSCA              5.27
# Name: 377, Length: 65, dtype: object
# Div                           E0
# Date                  15/05/2016
# HomeTeam    West Bromwich Albion
# AwayTeam               Liverpool
# FTHG                           1
#                     ...
# BbMxAHA                     1.86
# BbAvAHA                     1.81
# PSCH                        2.61
# PSCD                        3.75
# PSCA                         2.7
# Name: 378, Length: 65, dtype: object
# Div                   E0
# Date          11/05/2016
# HomeTeam    Norwich City
# AwayTeam         Watford
# FTHG                   4
#                 ...
# BbMxAHA             1.83
# BbAvAHA             1.79
# PSCH                1.88
# PSCD                3.98
# PSCA                4.19
# Name: 368, Length: 65, dtype: object
# Div                 E0
# Date        11/05/2016
# HomeTeam    Sunderland
# AwayTeam       Everton
# FTHG                 3
#                ...
# BbMxAHA           1.96
# BbAvAHA           1.92
# PSCH              1.86
# PSCD              3.98
# PSCA              4.31
# Name: 369, Length: 65, dtype: object
# Div                 E0
# Date        11/05/2016
# HomeTeam     Liverpool
# AwayTeam       Chelsea
# FTHG                 1
#                ...
# BbMxAHA           1.94
# BbAvAHA           1.89
# PSCH              1.71
# PSCD              4.36
# PSCA              4.81
# Name: 367, Length: 65, dtype: object
# Div                        E0
# Date               10/05/2016
# HomeTeam      West Ham United
# AwayTeam    Manchester United
# FTHG                        3
#                   ...
# BbMxAHA                  2.12
# BbAvAHA                  2.07
# PSCH                     3.15
# PSCD                     3.47
# PSCA                     2.41
# Name: 366, Length: 65, dtype: object
# Div                        E0
# Date               08/05/2016
# HomeTeam    Tottenham Hotspur
# AwayTeam          Southampton
# FTHG                        1
#                   ...
# BbMxAHA                  1.92
# BbAvAHA                  1.87
# PSCH                     2.25
# PSCD                     3.44
# PSCA                     3.49
# Name: 365, Length: 65, dtype: object
# Div                 E0
# Date        08/05/2016
# HomeTeam     Liverpool
# AwayTeam       Watford
# FTHG                 2
#                ...
# BbMxAHA           1.84
# BbAvAHA            1.8
# PSCH              1.55
# PSCD              4.48
# PSCA              6.55
# Name: 363, Length: 65, dtype: object
# Div                      E0
# Date             08/05/2016
# HomeTeam    Manchester City
# AwayTeam            Arsenal
# FTHG                      2
#                  ...
# BbMxAHA                2.11
# BbAvAHA                2.05
# PSCH                   2.22
# PSCD                   3.61
# PSCA                   3.41
# Name: 364, Length: 65, dtype: object
# Div                       E0
# Date              07/05/2016
# HomeTeam         Aston Villa
# AwayTeam    Newcastle United
# FTHG                       0
#                   ...
# BbMxAHA                 1.89
# BbAvAHA                 1.84
# PSCH                    5.05
# PSCD                    4.13
# PSCA                    1.72
# Name: 356, Length: 65, dtype: object
# Div                           E0
# Date                  07/05/2016
# HomeTeam         AFC Bournemouth
# AwayTeam    West Bromwich Albion
# FTHG                           1
#                     ...
# BbMxAHA                      2.0
# BbAvAHA                     1.95
# PSCH                        1.93
# PSCD                        3.65
# PSCA                        4.38
# Name: 357, Length: 65, dtype: object
# Div                     E0
# Date            07/05/2016
# HomeTeam    Leicester City
# AwayTeam           Everton
# FTHG                     3
#                  ...
# BbMxAHA               2.05
# BbAvAHA                2.0
# PSCH                  1.83
# PSCD                  4.21
# PSCA                  4.21
# Name: 359, Length: 65, dtype: object
# Div                        E0
# Date               07/05/2016
# HomeTeam         Norwich City
# AwayTeam    Manchester United
# FTHG                        0
#                   ...
# BbMxAHA                  1.88
# BbAvAHA                  1.85
# PSCH                     3.82
# PSCD                     3.53
# PSCA                     2.11
# Name: 360, Length: 65, dtype: object
# Div                     E0
# Date            07/05/2016
# HomeTeam    Crystal Palace
# AwayTeam        Stoke City
# FTHG                     2
#                  ...
# BbMxAHA               1.88
# BbAvAHA               1.84
# PSCH                  2.02
# PSCD                  3.54
# PSCA                  4.12
# Name: 358, Length: 65, dtype: object
# Div                 E0
# Date        07/05/2016
# HomeTeam    Sunderland
# AwayTeam       Chelsea
# FTHG                 3
#                ...
# BbMxAHA           2.15
# BbAvAHA           2.08
# PSCH              3.29
# PSCD              3.63
# PSCA              2.27
# Name: 361, Length: 65, dtype: object
# Div                      E0
# Date             07/05/2016
# HomeTeam    West Ham United
# AwayTeam       Swansea City
# FTHG                      1
#                  ...
# BbMxAHA                1.97
# BbAvAHA                1.92
# PSCH                   1.35
# PSCD                   5.73
# PSCA                   9.76
# Name: 362, Length: 65, dtype: object
# Div                        E0
# Date               02/05/2016
# HomeTeam              Chelsea
# AwayTeam    Tottenham Hotspur
# FTHG                        2
#                   ...
# BbMxAHA                  2.33
# BbAvAHA                  2.21
# PSCH                     2.58
# PSCD                     3.56
# PSCA                     2.85
# Name: 355, Length: 65, dtype: object
# Div                   E0
# Date          01/05/2016
# HomeTeam    Swansea City
# AwayTeam       Liverpool
# FTHG                   3
#                 ...
# BbMxAHA             2.07
# BbAvAHA             2.01
# PSCH                3.57
# PSCD                3.63
# PSCA                2.15
# Name: 354, Length: 65, dtype: object
# Div                        E0
# Date               01/05/2016
# HomeTeam    Manchester United
# AwayTeam       Leicester City
# FTHG                        1
#                   ...
# BbMxAHA                  1.88
# BbAvAHA                  1.84
# PSCH                      2.0
# PSCD                     3.49
# PSCA                     4.28
# Name: 352, Length: 65, dtype: object
# Div                      E0
# Date             01/05/2016
# HomeTeam        Southampton
# AwayTeam    Manchester City
# FTHG                      4
#                  ...
# BbMxAHA                1.98
# BbAvAHA                1.93
# PSCH                   2.42
# PSCD                   3.56
# PSCA                   3.06
# Name: 353, Length: 65, dtype: object
# Div                      E0
# Date             30/04/2016
# HomeTeam            Everton
# AwayTeam    AFC Bournemouth
# FTHG                      2
#                  ...
# BbMxAHA                1.94
# BbAvAHA                1.89
# PSCH                   2.42
# PSCD                   3.73
# PSCA                   2.95
# Name: 347, Length: 65, dtype: object
# Div                       E0
# Date              30/04/2016
# HomeTeam    Newcastle United
# AwayTeam      Crystal Palace
# FTHG                       1
#                   ...
# BbMxAHA                 1.91
# BbAvAHA                 1.87
# PSCH                    2.15
# PSCD                    3.57
# PSCA                    3.63
# Name: 348, Length: 65, dtype: object
# Div                 E0
# Date        30/04/2016
# HomeTeam    Stoke City
# AwayTeam    Sunderland
# FTHG                 1
#                ...
# BbMxAHA            1.7
# BbAvAHA           1.66
# PSCH              2.95
# PSCD              3.51
# PSCA              2.52
# Name: 349, Length: 65, dtype: object
# Div                  E0
# Date         30/04/2016
# HomeTeam        Watford
# AwayTeam    Aston Villa
# FTHG                  3
#                ...
# BbMxAHA            1.98
# BbAvAHA            1.93
# PSCH               1.77
# PSCD               3.78
# PSCA               5.26
# Name: 350, Length: 65, dtype: object
# Div                           E0
# Date                  30/04/2016
# HomeTeam    West Bromwich Albion
# AwayTeam         West Ham United
# FTHG                           0
#                     ...
# BbMxAHA                     2.05
# BbAvAHA                     2.01
# PSCH                        3.94
# PSCD                        3.68
# PSCA                        2.02
# Name: 351, Length: 65, dtype: object
# Div                   E0
# Date          30/04/2016
# HomeTeam         Arsenal
# AwayTeam    Norwich City
# FTHG                   1
#                 ...
# BbMxAHA             1.95
# BbAvAHA             1.89
# PSCH                1.25
# PSCD                 6.7
# PSCA               13.65
# Name: 346, Length: 65, dtype: object
# Div                           E0
# Date                  25/04/2016
# HomeTeam       Tottenham Hotspur
# AwayTeam    West Bromwich Albion
# FTHG                           1
#                     ...
# BbMxAHA                     2.05
# BbAvAHA                     1.98
# PSCH                        1.24
# PSCD                         6.9
# PSCA                       15.25
# Name: 345, Length: 65, dtype: object
# Div                 E0
# Date        24/04/2016
# HomeTeam    Sunderland
# AwayTeam       Arsenal
# FTHG                 0
#                ...
# BbMxAHA            2.0
# BbAvAHA           1.95
# PSCH              5.48
# PSCD              4.32
# PSCA              1.65
# Name: 344, Length: 65, dtype: object
# Div                     E0
# Date            24/04/2016
# HomeTeam    Leicester City
# AwayTeam      Swansea City
# FTHG                     4
#                  ...
# BbMxAHA               1.97
# BbAvAHA                1.9
# PSCH                  1.71
# PSCD                  3.87
# PSCA                  5.64
# Name: 343, Length: 65, dtype: object
# Div                  E0
# Date         23/04/2016
# HomeTeam    Aston Villa
# AwayTeam    Southampton
# FTHG                  2
#                ...
# BbMxAHA            2.02
# BbAvAHA            1.94
# PSCH               6.95
# PSCD               4.35
# PSCA               1.55
# Name: 339, Length: 65, dtype: object
# Div                      E0
# Date             23/04/2016
# HomeTeam    AFC Bournemouth
# AwayTeam            Chelsea
# FTHG                      1
#                  ...
# BbMxAHA                2.07
# BbAvAHA                2.01
# PSCH                   3.55
# PSCD                   3.68
# PSCA                   2.14
# Name: 340, Length: 65, dtype: object
# Div                       E0
# Date              23/04/2016
# HomeTeam           Liverpool
# AwayTeam    Newcastle United
# FTHG                       2
#                   ...
# BbMxAHA                 2.02
# BbAvAHA                 1.95
# PSCH                    1.52
# PSCD                    4.67
# PSCA                    6.69
# Name: 341, Length: 65, dtype: object
# Div                      E0
# Date             23/04/2016
# HomeTeam    Manchester City
# AwayTeam         Stoke City
# FTHG                      4
#                  ...
# BbMxAHA                2.06
# BbAvAHA                2.01
# PSCH                   1.31
# PSCD                    6.0
# PSCA                  11.35
# Name: 342, Length: 65, dtype: object
# Div                           E0
# Date                  21/04/2016
# HomeTeam                 Arsenal
# AwayTeam    West Bromwich Albion
# FTHG                           2
#                     ...
# BbMxAHA                      1.9
# BbAvAHA                     1.86
# PSCH                        1.25
# PSCD                        6.57
# PSCA                       13.99
# Name: 338, Length: 65, dtype: object
# Div                      E0
# Date             20/04/2016
# HomeTeam    West Ham United
# AwayTeam            Watford
# FTHG                      3
#                  ...
# BbMxAHA                1.97
# BbAvAHA                1.93
# PSCH                   1.45
# PSCD                   4.82
# PSCA                   8.03
# Name: 337, Length: 65, dtype: object
# Div                 E0
# Date        20/04/2016
# HomeTeam     Liverpool
# AwayTeam       Everton
# FTHG                 4
#                ...
# BbMxAHA           2.06
# BbAvAHA            2.0
# PSCH               1.7
# PSCD              4.07
# PSCA              5.31
# Name: 335, Length: 65, dtype: object
# Div                        E0
# Date               20/04/2016
# HomeTeam    Manchester United
# AwayTeam       Crystal Palace
# FTHG                        2
#                   ...
# BbMxAHA                  2.01
# BbAvAHA                  1.95
# PSCH                     1.46
# PSCD                     4.65
# PSCA                     8.25
# Name: 336, Length: 65, dtype: object
# Div                       E0
# Date              19/04/2016
# HomeTeam    Newcastle United
# AwayTeam     Manchester City
# FTHG                       1
#                   ...
# BbMxAHA                 1.98
# BbAvAHA                 1.93
# PSCH                     6.5
# PSCD                    4.63
# PSCA                    1.54
# Name: 334, Length: 65, dtype: object
# Div                        E0
# Date               18/04/2016
# HomeTeam           Stoke City
# AwayTeam    Tottenham Hotspur
# FTHG                        0
#                   ...
# BbMxAHA                  2.12
# BbAvAHA                  2.05
# PSCH                     5.02
# PSCD                      4.0
# PSCA                     1.75
# Name: 333, Length: 65, dtype: object
# Div                      E0
# Date             17/04/2016
# HomeTeam    AFC Bournemouth
# AwayTeam          Liverpool
# FTHG                      1
#                  ...
# BbMxAHA                1.88
# BbAvAHA                1.85
# PSCH                   2.69
# PSCD                   3.48
# PSCA                   2.77
# Name: 331, Length: 65, dtype: object
# Div                      E0
# Date             17/04/2016
# HomeTeam     Leicester City
# AwayTeam    West Ham United
# FTHG                      2
#                  ...
# BbMxAHA                2.02
# BbAvAHA                1.96
# PSCH                   1.95
# PSCD                   3.71
# PSCA                   4.19
# Name: 332, Length: 65, dtype: object
# Div                     E0
# Date            17/04/2016
# HomeTeam           Arsenal
# AwayTeam    Crystal Palace
# FTHG                     1
#                  ...
# BbMxAHA               1.93
# BbAvAHA               1.88
# PSCH                  1.34
# PSCD                  5.85
# PSCA                   9.7
# Name: 330, Length: 65, dtype: object
# Div                   E0
# Date          16/04/2016
# HomeTeam    Norwich City
# AwayTeam      Sunderland
# FTHG                   0
#                 ...
# BbMxAHA             1.92
# BbAvAHA             1.87
# PSCH                2.35
# PSCD                3.36
# PSCA                3.36
# Name: 328, Length: 65, dtype: object
# Div                  E0
# Date         16/04/2016
# HomeTeam        Everton
# AwayTeam    Southampton
# FTHG                  1
#                ...
# BbMxAHA            1.73
# BbAvAHA             1.7
# PSCH                3.0
# PSCD               3.52
# PSCA               2.48
# Name: 325, Length: 65, dtype: object
# Div                        E0
# Date               16/04/2016
# HomeTeam    Manchester United
# AwayTeam          Aston Villa
# FTHG                        1
#                   ...
# BbMxAHA                  1.95
# BbAvAHA                   1.9
# PSCH                     1.25
# PSCD                      6.4
# PSCA                     15.0
# Name: 326, Length: 65, dtype: object
# Div                       E0
# Date              16/04/2016
# HomeTeam    Newcastle United
# AwayTeam        Swansea City
# FTHG                       3
#                   ...
# BbMxAHA                 1.97
# BbAvAHA                 1.93
# PSCH                    2.43
# PSCD                    3.46
# PSCA                    3.13
# Name: 327, Length: 65, dtype: object
# Div                           E0
# Date                  16/04/2016
# HomeTeam    West Bromwich Albion
# AwayTeam                 Watford
# FTHG                           0
#                     ...
# BbMxAHA                     1.92
# BbAvAHA                     1.88
# PSCH                         2.4
# PSCD                        3.26
# PSCA                        3.37
# Name: 329, Length: 65, dtype: object
# Div                      E0
# Date             16/04/2016
# HomeTeam            Chelsea
# AwayTeam    Manchester City
# FTHG                      0
#                  ...
# BbMxAHA                1.97
# BbAvAHA                1.92
# PSCH                   2.61
# PSCD                   3.55
# PSCA                   2.81
# Name: 324, Length: 65, dtype: object
# Div                     E0
# Date            13/04/2016
# HomeTeam    Crystal Palace
# AwayTeam           Everton
# FTHG                     0
#                  ...
# BbMxAHA               2.23
# BbAvAHA               2.15
# PSCH                  2.68
# PSCD                  3.38
# PSCA                  2.85
# Name: 323, Length: 65, dtype: object
# Div                     E0
# Date            10/04/2016
# HomeTeam        Sunderland
# AwayTeam    Leicester City
# FTHG                     0
#                  ...
# BbMxAHA               1.92
# BbAvAHA               1.87
# PSCH                   3.3
# PSCD                  3.33
# PSCA                   2.4
# Name: 321, Length: 65, dtype: object
# Div                 E0
# Date        10/04/2016
# HomeTeam     Liverpool
# AwayTeam    Stoke City
# FTHG                 4
#                ...
# BbMxAHA           1.86
# BbAvAHA           1.83
# PSCH              1.65
# PSCD              3.98
# PSCA              6.15
# Name: 320, Length: 65, dtype: object
# Div                        E0
# Date               10/04/2016
# HomeTeam    Tottenham Hotspur
# AwayTeam    Manchester United
# FTHG                        3
#                   ...
# BbMxAHA                  2.02
# BbAvAHA                  1.97
# PSCH                      2.0
# PSCD                     3.54
# PSCA                      4.2
# Name: 322, Length: 65, dtype: object
# Div                      E0
# Date             09/04/2016
# HomeTeam    West Ham United
# AwayTeam            Arsenal
# FTHG                      3
#                  ...
# BbMxAHA                 2.0
# BbAvAHA                1.96
# PSCH                   3.89
# PSCD                   3.87
# PSCA                   1.98
# Name: 319, Length: 65, dtype: object
# Div                      E0
# Date             09/04/2016
# HomeTeam        Aston Villa
# AwayTeam    AFC Bournemouth
# FTHG                      1
#                  ...
# BbMxAHA                1.88
# BbAvAHA                1.84
# PSCH                   3.78
# PSCD                   3.58
# PSCA                    2.1
# Name: 313, Length: 65, dtype: object
# Div                     E0
# Date            09/04/2016
# HomeTeam    Crystal Palace
# AwayTeam      Norwich City
# FTHG                     1
#                  ...
# BbMxAHA               1.86
# BbAvAHA               1.81
# PSCH                  1.93
# PSCD                  3.53
# PSCA                  4.62
# Name: 314, Length: 65, dtype: object
# Div                       E0
# Date              09/04/2016
# HomeTeam         Southampton
# AwayTeam    Newcastle United
# FTHG                       3
#                   ...
# BbMxAHA                 1.91
# BbAvAHA                 1.87
# PSCH                    1.63
# PSCD                    4.24
# PSCA                    5.88
# Name: 316, Length: 65, dtype: object
# Div                   E0
# Date          09/04/2016
# HomeTeam    Swansea City
# AwayTeam         Chelsea
# FTHG                   1
#                 ...
# BbMxAHA             2.09
# BbAvAHA             2.05
# PSCH                3.08
# PSCD                 3.4
# PSCA                2.49
# Name: 317, Length: 65, dtype: object
# Div                 E0
# Date        09/04/2016
# HomeTeam       Watford
# AwayTeam       Everton
# FTHG                 1
#                ...
# BbMxAHA           1.96
# BbAvAHA           1.91
# PSCH              3.55
# PSCD              3.55
# PSCA              2.19
# Name: 318, Length: 65, dtype: object
# Div                           E0
# Date                  09/04/2016
# HomeTeam         Manchester City
# AwayTeam    West Bromwich Albion
# FTHG                           2
#                     ...
# BbMxAHA                     1.92
# BbAvAHA                     1.88
# PSCH                        1.36
# PSCD                        5.25
# PSCA                       10.75
# Name: 315, Length: 65, dtype: object
# Div                     E0
# Date            03/04/2016
# HomeTeam    Leicester City
# AwayTeam       Southampton
# FTHG                     1
#                  ...
# BbMxAHA               2.02
# BbAvAHA               1.97
# PSCH                  2.39
# PSCD                  3.32
# PSCA                  3.32
# Name: 311, Length: 65, dtype: object
# Div                        E0
# Date               03/04/2016
# HomeTeam    Manchester United
# AwayTeam              Everton
# FTHG                        1
#                   ...
# BbMxAHA                  1.87
# BbAvAHA                  1.83
# PSCH                     1.97
# PSCD                     3.65
# PSCA                     4.19
# Name: 312, Length: 65, dtype: object
# Div                  E0
# Date         02/04/2016
# HomeTeam    Aston Villa
# AwayTeam        Chelsea
# FTHG                  0
#                ...
# BbMxAHA            2.11
# BbAvAHA            2.05
# PSCH               4.93
# PSCD               3.63
# PSCA               1.85
# Name: 304, Length: 65, dtype: object
# Div                 E0
# Date        02/04/2016
# HomeTeam       Arsenal
# AwayTeam       Watford
# FTHG                 4
#                ...
# BbMxAHA           2.11
# BbAvAHA           2.07
# PSCH              1.35
# PSCD              5.55
# PSCA               9.9
# Name: 303, Length: 65, dtype: object
# Div                      E0
# Date             02/04/2016
# HomeTeam    AFC Bournemouth
# AwayTeam    Manchester City
# FTHG                      0
#                  ...
# BbMxAHA                2.11
# BbAvAHA                2.06
# PSCH                   3.94
# PSCD                   3.72
# PSCA                   2.01
# Name: 305, Length: 65, dtype: object
# Div                       E0
# Date              02/04/2016
# HomeTeam        Norwich City
# AwayTeam    Newcastle United
# FTHG                       3
#                   ...
# BbMxAHA                 2.07
# BbAvAHA                  2.0
# PSCH                    2.31
# PSCD                    3.35
# PSCA                    3.45
# Name: 307, Length: 65, dtype: object
# Div                   E0
# Date          02/04/2016
# HomeTeam      Stoke City
# AwayTeam    Swansea City
# FTHG                   2
#                 ...
# BbMxAHA             2.07
# BbAvAHA             2.02
# PSCH                2.13
# PSCD                3.37
# PSCA                3.96
# Name: 308, Length: 65, dtype: object
# Div                           E0
# Date                  02/04/2016
# HomeTeam              Sunderland
# AwayTeam    West Bromwich Albion
# FTHG                           0
#                     ...
# BbMxAHA                     1.85
# BbAvAHA                     1.81
# PSCH                         2.0
# PSCD                         3.4
# PSCA                        4.39
# Name: 309, Length: 65, dtype: object
# Div                      E0
# Date             02/04/2016
# HomeTeam    West Ham United
# AwayTeam     Crystal Palace
# FTHG                      2
#                  ...
# BbMxAHA                1.96
# BbAvAHA                1.92
# PSCH                   1.85
# PSCD                   3.74
# PSCA                   4.65
# Name: 310, Length: 65, dtype: object
# Div                        E0
# Date               02/04/2016
# HomeTeam            Liverpool
# AwayTeam    Tottenham Hotspur
# FTHG                        1
#                   ...
# BbMxAHA                  2.18
# BbAvAHA                   2.1
# PSCH                     2.15
# PSCD                     3.56
# PSCA                     3.66
# Name: 306, Length: 65, dtype: object
# Div                       E0
# Date              20/03/2016
# HomeTeam    Newcastle United
# AwayTeam          Sunderland
# FTHG                       1
#                   ...
# BbMxAHA                 2.14
# BbAvAHA                 2.06
# PSCH                    2.24
# PSCD                    3.22
# PSCA                    3.79
# Name: 300, Length: 65, dtype: object
# Div                        E0
# Date               20/03/2016
# HomeTeam      Manchester City
# AwayTeam    Manchester United
# FTHG                        0
#                   ...
# BbMxAHA                  2.12
# BbAvAHA                  2.04
# PSCH                     2.01
# PSCD                     3.61
# PSCA                     4.09
# Name: 299, Length: 65, dtype: object
# Div                        E0
# Date               20/03/2016
# HomeTeam    Tottenham Hotspur
# AwayTeam      AFC Bournemouth
# FTHG                        3
#                   ...
# BbMxAHA                  2.04
# BbAvAHA                  1.98
# PSCH                     1.52
# PSCD                     4.31
# PSCA                     7.55
# Name: 302, Length: 65, dtype: object
# Div                  E0
# Date         20/03/2016
# HomeTeam    Southampton
# AwayTeam      Liverpool
# FTHG                  3
#                ...
# BbMxAHA            2.47
# BbAvAHA             2.4
# PSCH               2.94
# PSCD                3.3
# PSCA               2.65
# Name: 301, Length: 65, dtype: object
# Div                 E0
# Date        19/03/2016
# HomeTeam       Everton
# AwayTeam       Arsenal
# FTHG                 0
#                ...
# BbMxAHA           2.35
# BbAvAHA           2.26
# PSCH               2.7
# PSCD              3.66
# PSCA              2.65
# Name: 295, Length: 65, dtype: object
# Div                      E0
# Date             19/03/2016
# HomeTeam            Chelsea
# AwayTeam    West Ham United
# FTHG                      2
#                  ...
# BbMxAHA                1.89
# BbAvAHA                1.66
# PSCH                   1.83
# PSCD                   3.76
# PSCA                   4.78
# Name: 293, Length: 65, dtype: object
# Div                     E0
# Date            19/03/2016
# HomeTeam    Crystal Palace
# AwayTeam    Leicester City
# FTHG                     0
#                  ...
# BbMxAHA               2.22
# BbAvAHA               2.13
# PSCH                  2.89
# PSCD                  3.35
# PSCA                  2.66
# Name: 294, Length: 65, dtype: object
# Div                 E0
# Date        19/03/2016
# HomeTeam       Watford
# AwayTeam    Stoke City
# FTHG                 1
#                ...
# BbMxAHA            1.9
# BbAvAHA           1.84
# PSCH              2.22
# PSCD              3.27
# PSCA              3.79
# Name: 297, Length: 65, dtype: object
# Div                           E0
# Date                  19/03/2016
# HomeTeam    West Bromwich Albion
# AwayTeam            Norwich City
# FTHG                           0
#                     ...
# BbMxAHA                     2.03
# BbAvAHA                     1.95
# PSCH                        2.44
# PSCD                        3.25
# PSCA                         3.3
# Name: 298, Length: 65, dtype: object
# Div                   E0
# Date          19/03/2016
# HomeTeam    Swansea City
# AwayTeam     Aston Villa
# FTHG                   1
#                 ...
# BbMxAHA             1.74
# BbAvAHA              1.7
# PSCH                1.68
# PSCD                4.05
# PSCA                5.55
# Name: 296, Length: 65, dtype: object
# Div                       E0
# Date              14/03/2016
# HomeTeam      Leicester City
# AwayTeam    Newcastle United
# FTHG                       1
#                   ...
# BbMxAHA                 1.91
# BbAvAHA                 1.86
# PSCH                    1.58
# PSCD                    4.36
# PSCA                    6.35
# Name: 292, Length: 65, dtype: object
# Div                        E0
# Date               13/03/2016
# HomeTeam          Aston Villa
# AwayTeam    Tottenham Hotspur
# FTHG                        0
#                   ...
# BbMxAHA                  1.88
# BbAvAHA                  1.83
# PSCH                     7.45
# PSCD                      4.5
# PSCA                     1.51
# Name: 291, Length: 65, dtype: object
# Div                      E0
# Date             12/03/2016
# HomeTeam       Norwich City
# AwayTeam    Manchester City
# FTHG                      0
#                  ...
# BbMxAHA                2.12
# BbAvAHA                2.03
# PSCH                   6.85
# PSCD                   4.31
# PSCA                   1.56
# Name: 289, Length: 65, dtype: object
# Div                      E0
# Date             12/03/2016
# HomeTeam    AFC Bournemouth
# AwayTeam       Swansea City
# FTHG                      3
#                  ...
# BbMxAHA                1.98
# BbAvAHA                1.92
# PSCH                   2.02
# PSCD                   3.54
# PSCA                   4.12
# Name: 288, Length: 65, dtype: object
# Div                  E0
# Date         12/03/2016
# HomeTeam     Stoke City
# AwayTeam    Southampton
# FTHG                  1
#                ...
# BbMxAHA            2.02
# BbAvAHA            1.97
# PSCH               2.72
# PSCD               3.25
# PSCA                2.9
# Name: 290, Length: 65, dtype: object
# Div                     E0
# Date            06/03/2016
# HomeTeam    Crystal Palace
# AwayTeam         Liverpool
# FTHG                     1
#                  ...
# BbMxAHA               1.86
# BbAvAHA               1.81
# PSCH                  3.78
# PSCD                  3.51
# PSCA                  2.13
# Name: 286, Length: 65, dtype: object
# Div                           E0
# Date                  06/03/2016
# HomeTeam    West Bromwich Albion
# AwayTeam       Manchester United
# FTHG                           1
#                     ...
# BbMxAHA                      2.4
# BbAvAHA                     2.31
# PSCH                        4.45
# PSCD                        3.61
# PSCA                        1.93
# Name: 287, Length: 65, dtype: object
# Div                 E0
# Date        05/03/2016
# HomeTeam       Chelsea
# AwayTeam    Stoke City
# FTHG                 1
#                ...
# BbMxAHA           2.11
# BbAvAHA           2.05
# PSCH              1.52
# PSCD              4.32
# PSCA              7.63
# Name: 278, Length: 65, dtype: object
# Div                      E0
# Date             05/03/2016
# HomeTeam            Everton
# AwayTeam    West Ham United
# FTHG                      2
#                  ...
# BbMxAHA                1.77
# BbAvAHA                1.72
# PSCH                   1.67
# PSCD                   4.27
# PSCA                   5.39
# Name: 279, Length: 65, dtype: object
# Div                      E0
# Date             05/03/2016
# HomeTeam    Manchester City
# AwayTeam        Aston Villa
# FTHG                      4
#                  ...
# BbMxAHA                 1.9
# BbAvAHA                1.82
# PSCH                   1.19
# PSCD                   7.99
# PSCA                  18.14
# Name: 280, Length: 65, dtype: object
# Div                       E0
# Date              05/03/2016
# HomeTeam    Newcastle United
# AwayTeam     AFC Bournemouth
# FTHG                       1
#                   ...
# BbMxAHA                  2.0
# BbAvAHA                 1.96
# PSCH                    2.59
# PSCD                     3.4
# PSCA                    2.94
# Name: 281, Length: 65, dtype: object
# Div                  E0
# Date         05/03/2016
# HomeTeam    Southampton
# AwayTeam     Sunderland
# FTHG                  1
#                ...
# BbMxAHA            1.86
# BbAvAHA            1.82
# PSCH               1.62
# PSCD                4.2
# PSCA               6.07
# Name: 282, Length: 65, dtype: object
# Div                     E0
# Date            05/03/2016
# HomeTeam           Watford
# AwayTeam    Leicester City
# FTHG                     0
#                  ...
# BbMxAHA               2.21
# BbAvAHA               2.14
# PSCH                  2.99
# PSCD                  3.39
# PSCA                  2.56
# Name: 285, Length: 65, dtype: object
# Div                        E0
# Date               05/03/2016
# HomeTeam    Tottenham Hotspur
# AwayTeam              Arsenal
# FTHG                        2
#                   ...
# BbMxAHA                   1.9
# BbAvAHA                  1.85
# PSCH                     2.31
# PSCD                     3.51
# PSCA                     3.29
# Name: 284, Length: 65, dtype: object
# Div                   E0
# Date          05/03/2016
# HomeTeam    Swansea City
# AwayTeam    Norwich City
# FTHG                   1
#                 ...
# BbMxAHA             2.23
# BbAvAHA             2.18
# PSCH                2.16
# PSCD                3.33
# PSCA                3.89
# Name: 283, Length: 65, dtype: object
# Div                   E0
# Date          02/03/2016
# HomeTeam         Arsenal
# AwayTeam    Swansea City
# FTHG                   1
#                 ...
# BbMxAHA             1.86
# BbAvAHA              1.8
# PSCH                1.29
# PSCD                5.95
# PSCA               12.55
# Name: 273, Length: 65, dtype: object
# Div                       E0
# Date              02/03/2016
# HomeTeam          Stoke City
# AwayTeam    Newcastle United
# FTHG                       1
#                   ...
# BbMxAHA                 2.28
# BbAvAHA                 2.23
# PSCH                    2.06
# PSCD                    3.51
# PSCA                     4.0
# Name: 276, Length: 65, dtype: object
# Div                        E0
# Date               02/03/2016
# HomeTeam      West Ham United
# AwayTeam    Tottenham Hotspur
# FTHG                        1
#                   ...
# BbMxAHA                  1.76
# BbAvAHA                  1.72
# PSCH                      3.6
# PSCD                     3.38
# PSCA                     2.24
# Name: 277, Length: 65, dtype: object
# Div                      E0
# Date             02/03/2016
# HomeTeam          Liverpool
# AwayTeam    Manchester City
# FTHG                      3
#                  ...
# BbMxAHA                1.75
# BbAvAHA                1.71
# PSCH                   2.79
# PSCD                   3.53
# PSCA                   2.64
# Name: 274, Length: 65, dtype: object
# Div                        E0
# Date               02/03/2016
# HomeTeam    Manchester United
# AwayTeam              Watford
# FTHG                        1
#                   ...
# BbMxAHA                  1.76
# BbAvAHA                  1.72
# PSCH                     1.64
# PSCD                     3.99
# PSCA                      6.3
# Name: 275, Length: 65, dtype: object
# Div                  E0
# Date         01/03/2016
# HomeTeam    Aston Villa
# AwayTeam        Everton
# FTHG                  1
#                ...
# BbMxAHA             2.2
# BbAvAHA            2.13
# PSCH               5.48
# PSCD               4.14
# PSCA               1.68
# Name: 268, Length: 65, dtype: object
# Div                      E0
# Date             01/03/2016
# HomeTeam    AFC Bournemouth
# AwayTeam        Southampton
# FTHG                      2
#                  ...
# BbMxAHA                1.92
# BbAvAHA                1.85
# PSCH                   2.86
# PSCD                   3.26
# PSCA                   2.74
# Name: 269, Length: 65, dtype: object
# Div                           E0
# Date                  01/03/2016
# HomeTeam          Leicester City
# AwayTeam    West Bromwich Albion
# FTHG                           2
#                     ...
# BbMxAHA                      1.7
# BbAvAHA                     1.65
# PSCH                        1.68
# PSCD                        3.95
# PSCA                        5.87
# Name: 270, Length: 65, dtype: object
# Div                   E0
# Date          01/03/2016
# HomeTeam    Norwich City
# AwayTeam         Chelsea
# FTHG                   1
#                 ...
# BbMxAHA             2.26
# BbAvAHA             2.19
# PSCH                5.56
# PSCD                3.86
# PSCA                1.72
# Name: 271, Length: 65, dtype: object
# Div                     E0
# Date            01/03/2016
# HomeTeam        Sunderland
# AwayTeam    Crystal Palace
# FTHG                     2
#                  ...
# BbMxAHA               1.84
# BbAvAHA                1.8
# PSCH                  2.49
# PSCD                  3.27
# PSCA                  3.19
# Name: 272, Length: 65, dtype: object
# Div                        E0
# Date               28/02/2016
# HomeTeam    Manchester United
# AwayTeam              Arsenal
# FTHG                        3
#                   ...
# BbMxAHA                  2.05
# BbAvAHA                   2.0
# PSCH                     3.46
# PSCD                      3.4
# PSCA                     2.29
# Name: 267, Length: 65, dtype: object
# Div                        E0
# Date               28/02/2016
# HomeTeam    Tottenham Hotspur
# AwayTeam         Swansea City
# FTHG                        2
#                   ...
# BbMxAHA                  1.65
# BbAvAHA                   1.6
# PSCH                      1.5
# PSCD                     4.22
# PSCA                     8.62
# Name: 266, Length: 65, dtype: object
# Div                      E0
# Date             27/02/2016
# HomeTeam    West Ham United
# AwayTeam         Sunderland
# FTHG                      1
#                  ...
# BbMxAHA                1.83
# BbAvAHA                1.79
# PSCH                   1.86
# PSCD                    3.7
# PSCA                   4.69
# Name: 265, Length: 65, dtype: object
# Div                     E0
# Date            27/02/2016
# HomeTeam    Leicester City
# AwayTeam      Norwich City
# FTHG                     1
#                  ...
# BbMxAHA               1.97
# BbAvAHA               1.93
# PSCH                  1.57
# PSCD                  4.19
# PSCA                  6.95
# Name: 260, Length: 65, dtype: object
# Div                  E0
# Date         27/02/2016
# HomeTeam    Southampton
# AwayTeam        Chelsea
# FTHG                  1
#                ...
# BbMxAHA            2.27
# BbAvAHA             2.2
# PSCH               3.23
# PSCD                3.3
# PSCA               2.45
# Name: 261, Length: 65, dtype: object
# Div                  E0
# Date         27/02/2016
# HomeTeam     Stoke City
# AwayTeam    Aston Villa
# FTHG                  2
#                ...
# BbMxAHA             1.7
# BbAvAHA            1.67
# PSCH               1.92
# PSCD               3.45
# PSCA               4.78
# Name: 262, Length: 65, dtype: object
# Div                      E0
# Date             27/02/2016
# HomeTeam            Watford
# AwayTeam    AFC Bournemouth
# FTHG                      0
#                  ...
# BbMxAHA                1.88
# BbAvAHA                1.83
# PSCH                   2.64
# PSCD                   3.36
# PSCA                   2.91
# Name: 263, Length: 65, dtype: object
# Div                           E0
# Date                  27/02/2016
# HomeTeam    West Bromwich Albion
# AwayTeam          Crystal Palace
# FTHG                           3
#                     ...
# BbMxAHA                     1.99
# BbAvAHA                     1.94
# PSCH                        2.96
# PSCD                        3.23
# PSCA                        2.68
# Name: 264, Length: 65, dtype: object
# Div                     E0
# Date            14/02/2016
# HomeTeam           Arsenal
# AwayTeam    Leicester City
# FTHG                     2
#                  ...
# BbMxAHA               1.75
# BbAvAHA                1.7
# PSCH                  1.68
# PSCD                  4.23
# PSCA                  5.32
# Name: 257, Length: 65, dtype: object
# Div                  E0
# Date         14/02/2016
# HomeTeam    Aston Villa
# AwayTeam      Liverpool
# FTHG                  0
#                ...
# BbMxAHA            2.15
# BbAvAHA            2.09
# PSCH               5.81
# PSCD               3.87
# PSCA               1.69
# Name: 258, Length: 65, dtype: object
# Div                        E0
# Date               14/02/2016
# HomeTeam      Manchester City
# AwayTeam    Tottenham Hotspur
# FTHG                        1
#                   ...
# BbMxAHA                  2.18
# BbAvAHA                  2.09
# PSCH                     2.15
# PSCD                     3.44
# PSCA                     3.78
# Name: 259, Length: 65, dtype: object
# Div                        E0
# Date               13/02/2016
# HomeTeam           Sunderland
# AwayTeam    Manchester United
# FTHG                        2
#                   ...
# BbMxAHA                  2.52
# BbAvAHA                   2.4
# PSCH                     5.27
# PSCD                     3.69
# PSCA                     1.79
# Name: 255, Length: 65, dtype: object
# Div                      E0
# Date             13/02/2016
# HomeTeam    AFC Bournemouth
# AwayTeam         Stoke City
# FTHG                      1
#                  ...
# BbMxAHA                 2.2
# BbAvAHA                2.12
# PSCH                   1.95
# PSCD                   3.57
# PSCA                   4.38
# Name: 250, Length: 65, dtype: object
# Div                     E0
# Date            13/02/2016
# HomeTeam    Crystal Palace
# AwayTeam           Watford
# FTHG                     1
#                  ...
# BbMxAHA               2.04
# BbAvAHA               1.99
# PSCH                  2.23
# PSCD                  3.25
# PSCA                  3.78
# Name: 252, Length: 65, dtype: object
# Div                           E0
# Date                  13/02/2016
# HomeTeam                 Everton
# AwayTeam    West Bromwich Albion
# FTHG                           0
#                     ...
# BbMxAHA                     2.06
# BbAvAHA                      2.0
# PSCH                         1.5
# PSCD                        4.49
# PSCA                         7.6
# Name: 253, Length: 65, dtype: object
# Div                      E0
# Date             13/02/2016
# HomeTeam       Norwich City
# AwayTeam    West Ham United
# FTHG                      2
#                  ...
# BbMxAHA                1.88
# BbAvAHA                1.83
# PSCH                    2.5
# PSCD                   3.33
# PSCA                   3.12
# Name: 254, Length: 65, dtype: object
# Div                   E0
# Date          13/02/2016
# HomeTeam    Swansea City
# AwayTeam     Southampton
# FTHG                   0
#                 ...
# BbMxAHA              2.1
# BbAvAHA             2.04
# PSCH                 3.2
# PSCD                3.25
# PSCA                2.51
# Name: 256, Length: 65, dtype: object
# Div                       E0
# Date              13/02/2016
# HomeTeam             Chelsea
# AwayTeam    Newcastle United
# FTHG                       5
#                   ...
# BbMxAHA                 2.27
# BbAvAHA                  2.2
# PSCH                    1.39
# PSCD                     5.2
# PSCA                     9.1
# Name: 251, Length: 65, dtype: object
# Div                      E0
# Date             07/02/2016
# HomeTeam    AFC Bournemouth
# AwayTeam            Arsenal
# FTHG                      0
#                  ...
# BbMxAHA                2.09
# BbAvAHA                2.04
# PSCH                   4.53
# PSCD                   3.66
# PSCA                    1.9
# Name: 248, Length: 65, dtype: object
# Div                        E0
# Date               07/02/2016
# HomeTeam              Chelsea
# AwayTeam    Manchester United
# FTHG                        1
#                   ...
# BbMxAHA                  1.85
# BbAvAHA                   1.8
# PSCH                     2.14
# PSCD                     3.35
# PSCA                     3.94
# Name: 249, Length: 65, dtype: object
# Div                      E0
# Date             06/02/2016
# HomeTeam    Manchester City
# AwayTeam     Leicester City
# FTHG                      1
#                  ...
# BbMxAHA                1.91
# BbAvAHA                1.86
# PSCH                    1.6
# PSCD                   4.29
# PSCA                   6.21
# Name: 242, Length: 65, dtype: object
# Div                   E0
# Date          06/02/2016
# HomeTeam     Aston Villa
# AwayTeam    Norwich City
# FTHG                   2
#                 ...
# BbMxAHA             1.89
# BbAvAHA             1.85
# PSCH                2.56
# PSCD                3.21
# PSCA                3.15
# Name: 240, Length: 65, dtype: object
# Div                 E0
# Date        06/02/2016
# HomeTeam     Liverpool
# AwayTeam    Sunderland
# FTHG                 2
#                ...
# BbMxAHA           1.68
# BbAvAHA           1.66
# PSCH              1.43
# PSCD              4.86
# PSCA               8.6
# Name: 241, Length: 65, dtype: object
# Div                           E0
# Date                  06/02/2016
# HomeTeam        Newcastle United
# AwayTeam    West Bromwich Albion
# FTHG                           1
#                     ...
# BbMxAHA                      2.1
# BbAvAHA                     2.03
# PSCH                        2.29
# PSCD                        3.31
# PSCA                        3.55
# Name: 243, Length: 65, dtype: object
# Div                 E0
# Date        06/02/2016
# HomeTeam    Stoke City
# AwayTeam       Everton
# FTHG                 0
#                ...
# BbMxAHA           1.75
# BbAvAHA            1.7
# PSCH              2.94
# PSCD              3.38
# PSCA               2.6
# Name: 245, Length: 65, dtype: object
# Div                     E0
# Date            06/02/2016
# HomeTeam      Swansea City
# AwayTeam    Crystal Palace
# FTHG                     1
#                  ...
# BbMxAHA               2.01
# BbAvAHA               1.97
# PSCH                  2.39
# PSCD                  3.22
# PSCA                  3.44
# Name: 246, Length: 65, dtype: object
# Div                        E0
# Date               06/02/2016
# HomeTeam    Tottenham Hotspur
# AwayTeam              Watford
# FTHG                        1
#                   ...
# BbMxAHA                   2.1
# BbAvAHA                  2.04
# PSCH                     1.52
# PSCD                      4.4
# PSCA                     7.38
# Name: 247, Length: 65, dtype: object
# Div                      E0
# Date             06/02/2016
# HomeTeam        Southampton
# AwayTeam    West Ham United
# FTHG                      1
#                  ...
# BbMxAHA                1.97
# BbAvAHA                1.93
# PSCH                   1.71
# PSCD                   3.98
# PSCA                   5.42
# Name: 244, Length: 65, dtype: object
# Div                       E0
# Date              03/02/2016
# HomeTeam             Everton
# AwayTeam    Newcastle United
# FTHG                       3
#                   ...
# BbMxAHA                  1.8
# BbAvAHA                 1.76
# ...
# AvgCAHA                  1.92
# Name: 47, Length: 106, dtype: object
# Div                       E0
# Date              31/08/2022
# Time                   20:00
# HomeTeam           Liverpool
# AwayTeam    Newcastle United
#                   ...
# PCAHA                   2.17
# MaxCAHH                 1.97
# MaxCAHA                 2.26
# AvgCAHH                 1.78
# AvgCAHA                 2.12
# Name: 48, Length: 106, dtype: object
# Div                     E0
# Date            30/08/2022
# Time                 19:30
# HomeTeam    Crystal Palace
# AwayTeam         Brentford
#                  ...
# PCAHA                 1.81
# MaxCAHH               2.14
# MaxCAHA               1.85
# AvgCAHH               2.07
# AvgCAHA               1.81
# Name: 40, Length: 106, dtype: object
# Div                             E0
# Date                    30/08/2022
# Time                         19:30
# HomeTeam                    Fulham
# AwayTeam    Brighton & Hove Albion
#                      ...
# PCAHA                         2.03
# MaxCAHH                       1.94
# MaxCAHA                       2.04
# AvgCAHH                        1.9
# AvgCAHA                       1.97
# Name: 41, Length: 106, dtype: object
# Div                  E0
# Date         30/08/2022
# Time              19:45
# HomeTeam    Southampton
# AwayTeam        Chelsea
#                ...
# PCAHA              1.88
# MaxCAHH            2.11
# MaxCAHA            1.88
# AvgCAHH            2.06
# AvgCAHA            1.83
# Name: 42, Length: 106, dtype: object
# Div                   E0
# Date          30/08/2022
# Time               20:00
# HomeTeam    Leeds United
# AwayTeam         Everton
#                 ...
# PCAHA               2.06
# MaxCAHH             1.88
# MaxCAHA             2.09
# AvgCAHH             1.84
# AvgCAHA             2.04
# Name: 43, Length: 106, dtype: object
# Div                      E0
# Date             28/08/2022
# Time                  14:00
# HomeTeam        Aston Villa
# AwayTeam    West Ham United
#                  ...
# PCAHA                  1.82
# MaxCAHH                2.14
# MaxCAHA                1.88
# AvgCAHH                2.09
# AvgCAHA                 1.8
# Name: 37, Length: 106, dtype: object
# Div                              E0
# Date                     28/08/2022
# Time                          14:00
# HomeTeam    Wolverhampton Wanderers
# AwayTeam           Newcastle United
#                      ...
# PCAHA                          1.75
# MaxCAHH                        2.23
# MaxCAHA                         1.8
# AvgCAHH                        2.14
# AvgCAHA                        1.75
# Name: 38, Length: 106, dtype: object
# Div                        E0
# Date               28/08/2022
# Time                    16:30
# HomeTeam    Nottingham Forest
# AwayTeam    Tottenham Hotspur
#                   ...
# PCAHA                    2.06
# MaxCAHH                  1.95
# MaxCAHA                   2.1
# AvgCAHH                  1.86
# AvgCAHA                  2.01
# Name: 39, Length: 106, dtype: object
# Div                        E0
# Date               27/08/2022
# Time                    12:30
# HomeTeam          Southampton
# AwayTeam    Manchester United
#                   ...
# PCAHA                    2.02
# MaxCAHH                   2.1
# MaxCAHA                  2.02
# AvgCAHH                  1.93
# AvgCAHA                  1.94
# Name: 30, Length: 106, dtype: object
# Div                 E0
# Date        27/08/2022
# Time             15:00
# HomeTeam     Brentford
# AwayTeam       Everton
#                ...
# PCAHA             1.86
# MaxCAHH           2.16
# MaxCAHA           1.86
# AvgCAHH           2.08
# AvgCAHA            1.8
# Name: 31, Length: 106, dtype: object
# Div                             E0
# Date                    27/08/2022
# Time                         15:00
# HomeTeam    Brighton & Hove Albion
# AwayTeam              Leeds United
#                      ...
# PCAHA                         1.98
# MaxCAHH                       2.12
# MaxCAHA                       2.01
# AvgCAHH                       1.96
# AvgCAHA                       1.92
# Name: 32, Length: 106, dtype: object
# Div                     E0
# Date            27/08/2022
# Time                 15:00
# HomeTeam           Chelsea
# AwayTeam    Leicester City
#                  ...
# PCAHA                 2.05
# MaxCAHH               1.95
# MaxCAHA               2.08
# AvgCAHH               1.88
# AvgCAHA                2.0
# Name: 33, Length: 106, dtype: object
# Div                      E0
# Date             27/08/2022
# Time                  15:00
# HomeTeam          Liverpool
# AwayTeam    AFC Bournemouth
#                  ...
# PCAHA                  1.97
# MaxCAHH                1.95
# MaxCAHA                2.27
# AvgCAHH                1.87
# AvgCAHA                2.01
# Name: 34, Length: 106, dtype: object
# Div                      E0
# Date             27/08/2022
# Time                  15:00
# HomeTeam    Manchester City
# AwayTeam     Crystal Palace
#                  ...
# PCAHA                  1.95
# MaxCAHH                2.01
# MaxCAHA                1.99
# AvgCAHH                1.93
# AvgCAHA                1.94
# Name: 35, Length: 106, dtype: object
# Div                 E0
# Date        27/08/2022
# Time             17:30
# HomeTeam       Arsenal
# AwayTeam        Fulham
#                ...
# PCAHA             1.79
# MaxCAHH           2.15
# MaxCAHA           2.04
# AvgCAHH           2.03
# AvgCAHA           1.84
# Name: 36, Length: 106, dtype: object
# Div                        E0
# Date               22/08/2022
# Time                    20:00
# HomeTeam    Manchester United
# AwayTeam            Liverpool
#                   ...
# PCAHA                    1.88
# MaxCAHH                  2.07
# MaxCAHA                   1.9
# AvgCAHH                  2.01
# AvgCAHA                  1.86
# Name: 29, Length: 106, dtype: object
# Div                   E0
# Date          21/08/2022
# Time               14:00
# HomeTeam    Leeds United
# AwayTeam         Chelsea
#                 ...
# PCAHA               1.87
# MaxCAHH             2.12
# MaxCAHA             1.94
# AvgCAHH             2.03
# AvgCAHA             1.84
# Name: 26, Length: 106, dtype: object
# Div                             E0
# Date                    21/08/2022
# Time                         14:00
# HomeTeam           West Ham United
# AwayTeam    Brighton & Hove Albion
#                      ...
# PCAHA                         2.08
# MaxCAHH                       1.86
# MaxCAHA                       2.12
# AvgCAHH                       1.81
# AvgCAHA                       2.08
# Name: 27, Length: 106, dtype: object
# Div                       E0
# Date              21/08/2022
# Time                   16:30
# HomeTeam    Newcastle United
# AwayTeam     Manchester City
#                   ...
# PCAHA                   2.04
# MaxCAHH                 2.04
# MaxCAHA                 2.09
# AvgCAHH                  1.9
# AvgCAHA                 1.97
# Name: 28, Length: 106, dtype: object
# Div                              E0
# Date                     20/08/2022
# Time                          12:30
# HomeTeam          Tottenham Hotspur
# AwayTeam    Wolverhampton Wanderers
#                      ...
# PCAHA                          1.88
# MaxCAHH                        2.06
# MaxCAHA                        1.98
# AvgCAHH                         2.0
# AvgCAHA                        1.88
# Name: 20, Length: 106, dtype: object
# Div                     E0
# Date            20/08/2022
# Time                 15:00
# HomeTeam    Crystal Palace
# AwayTeam       Aston Villa
#                  ...
# PCAHA                 1.78
# MaxCAHH               2.19
# MaxCAHA               1.83
# AvgCAHH               2.12
# AvgCAHA               1.77
# Name: 21, Length: 106, dtype: object
# Div                        E0
# Date               20/08/2022
# Time                    15:00
# HomeTeam              Everton
# AwayTeam    Nottingham Forest
#                   ...
# PCAHA                    2.03
# MaxCAHH                  1.96
# MaxCAHA                  2.08
# AvgCAHH                   1.9
# AvgCAHA                  1.97
# Name: 22, Length: 106, dtype: object
# Div                 E0
# Date        20/08/2022
# Time             15:00
# HomeTeam        Fulham
# AwayTeam     Brentford
#                ...
# PCAHA              2.0
# MaxCAHH           1.94
# MaxCAHA           2.02
# AvgCAHH           1.91
# AvgCAHA           1.97
# Name: 23, Length: 106, dtype: object
# Div                     E0
# Date            20/08/2022
# Time                 15:00
# HomeTeam    Leicester City
# AwayTeam       Southampton
#                  ...
# PCAHA                 1.94
# MaxCAHH               2.14
# MaxCAHA               1.98
# AvgCAHH               1.98
# AvgCAHA                1.9
# Name: 24, Length: 106, dtype: object
# Div                      E0
# Date             20/08/2022
# Time                  17:30
# HomeTeam    AFC Bournemouth
# AwayTeam            Arsenal
#                  ...
# PCAHA                  2.05
# MaxCAHH                1.93
# MaxCAHA                2.05
# AvgCAHH                1.88
# AvgCAHA                1.99
# Name: 25, Length: 106, dtype: object
# Div                     E0
# Date            15/08/2022
# Time                 20:00
# HomeTeam         Liverpool
# AwayTeam    Crystal Palace
#                  ...
# PCAHA                 1.83
# MaxCAHH               2.08
# MaxCAHA               2.09
# AvgCAHH               2.02
# AvgCAHA               1.86
# Name: 19, Length: 106, dtype: object
# Div                        E0
# Date               14/08/2022
# Time                    14:00
# HomeTeam    Nottingham Forest
# AwayTeam      West Ham United
#                   ...
# PCAHA                    1.99
# MaxCAHH                  1.96
# MaxCAHA                  2.04
# AvgCAHH                  1.92
# AvgCAHA                  1.95
# Name: 17, Length: 106, dtype: object
# Div                        E0
# Date               14/08/2022
# Time                    16:30
# HomeTeam              Chelsea
# AwayTeam    Tottenham Hotspur
#                   ...
# PCAHA                    2.07
# MaxCAHH                  1.92
# MaxCAHA                  2.07
# AvgCAHH                  1.86
# AvgCAHA                  2.02
# Name: 18, Length: 106, dtype: object
# Div                  E0
# Date         13/08/2022
# Time              12:30
# HomeTeam    Aston Villa
# AwayTeam        Everton
#                ...
# PCAHA              1.87
# MaxCAHH            2.07
# MaxCAHA             1.9
# AvgCAHH            2.02
# AvgCAHA            1.86
# Name: 10, Length: 106, dtype: object
# Div                     E0
# Date            13/08/2022
# Time                 15:00
# HomeTeam           Arsenal
# AwayTeam    Leicester City
#                  ...
# PCAHA                 1.96
# MaxCAHH               1.99
# MaxCAHA                2.0
# AvgCAHH               1.94
# AvgCAHA               1.94
# Name: 11, Length: 106, dtype: object
# Div                             E0
# Date                    13/08/2022
# Time                         15:00
# HomeTeam    Brighton & Hove Albion
# AwayTeam          Newcastle United
#                      ...
# PCAHA                         1.82
# MaxCAHH                       2.14
# MaxCAHA                       1.84
# AvgCAHH                       2.08
# AvgCAHA                       1.81
# Name: 12, Length: 106, dtype: object
# Div                      E0
# Date             13/08/2022
# Time                  15:00
# HomeTeam    Manchester City
# AwayTeam    AFC Bournemouth
#                  ...
# PCAHA                  1.94
# MaxCAHH                1.98
# MaxCAHA                2.02
# AvgCAHH                1.92
# AvgCAHA                1.95
# Name: 13, Length: 106, dtype: object
# Div                   E0
# Date          13/08/2022
# Time               15:00
# HomeTeam     Southampton
# AwayTeam    Leeds United
#                 ...
# PCAHA               1.83
# MaxCAHH             2.13
# MaxCAHA             1.84
# AvgCAHH              2.1
# AvgCAHA             1.79
# Name: 14, Length: 106, dtype: object
# Div                              E0
# Date                     13/08/2022
# Time                          15:00
# HomeTeam    Wolverhampton Wanderers
# AwayTeam                     Fulham
#                      ...
# PCAHA                          2.01
# MaxCAHH                        1.95
# MaxCAHA                        2.05
# AvgCAHH                         1.9
# AvgCAHA                        1.98
# Name: 15, Length: 106, dtype: object
# Div                        E0
# Date               13/08/2022
# Time                    17:30
# HomeTeam            Brentford
# AwayTeam    Manchester United
#                   ...
# PCAHA                    1.78
# MaxCAHH                  2.19
# MaxCAHA                  1.95
# AvgCAHH                  2.04
# AvgCAHA                  1.84
# Name: 16, Length: 106, dtype: object
# Div                     E0
# Date            07/08/2022
# Time                 14:00
# HomeTeam    Leicester City
# AwayTeam         Brentford
#                  ...
# PCAHA                 1.96
# MaxCAHH               1.96
# MaxCAHA               2.04
# AvgCAHH               1.92
# AvgCAHA               1.96
# Name: 7, Length: 106, dtype: object
# Div                             E0
# Date                    07/08/2022
# Time                         14:00
# HomeTeam         Manchester United
# AwayTeam    Brighton & Hove Albion
#                      ...
# PCAHA                         1.88
# MaxCAHH                       2.08
# MaxCAHA                       1.97
# AvgCAHH                        2.0
# AvgCAHA                       1.88
# Name: 8, Length: 106, dtype: object
# Div                      E0
# Date             07/08/2022
# Time                  16:30
# HomeTeam    West Ham United
# AwayTeam    Manchester City
#                  ...
# PCAHA                  2.08
# MaxCAHH                 2.0
# MaxCAHA                2.12
# AvgCAHH                1.85
# AvgCAHA                2.04
# Name: 9, Length: 106, dtype: object
# Div                 E0
# Date        06/08/2022
# Time             12:30
# HomeTeam        Fulham
# AwayTeam     Liverpool
#                ...
# PCAHA             2.02
# MaxCAHH           2.01
# MaxCAHA           2.06
# AvgCAHH           1.89
# AvgCAHA           1.99
# Name: 1, Length: 106, dtype: object
# Div                      E0
# Date             06/08/2022
# Time                  15:00
# HomeTeam    AFC Bournemouth
# AwayTeam        Aston Villa
#                  ...
# PCAHA                   2.0
# MaxCAHH                1.94
# MaxCAHA                2.04
# AvgCAHH                1.88
# AvgCAHA                 2.0
# Name: 2, Length: 106, dtype: object
# Div                              E0
# Date                     06/08/2022
# Time                          15:00
# HomeTeam               Leeds United
# AwayTeam    Wolverhampton Wanderers
#                      ...
# PCAHA                          1.84
# MaxCAHH                        2.14
# MaxCAHA                        1.87
# AvgCAHH                        2.08
# AvgCAHA                        1.81
# Name: 3, Length: 106, dtype: object
# Div                        E0
# Date               06/08/2022
# Time                    15:00
# HomeTeam     Newcastle United
# AwayTeam    Nottingham Forest
#                   ...
# PCAHA                    1.93
# MaxCAHH                  2.19
# MaxCAHA                  1.97
# AvgCAHH                  2.03
# AvgCAHA                  1.86
# Name: 4, Length: 106, dtype: object
# Div                        E0
# Date               06/08/2022
# Time                    15:00
# HomeTeam    Tottenham Hotspur
# AwayTeam          Southampton
#                   ...
# PCAHA                    1.88
# MaxCAHH                  2.08
# MaxCAHA                  1.88
# AvgCAHH                  2.03
# AvgCAHA                  1.85
# Name: 5, Length: 106, dtype: object
# Div                 E0
# Date        06/08/2022
# Time             17:30
# HomeTeam       Everton
# AwayTeam       Chelsea
#                ...
# PCAHA             1.98
# MaxCAHH           1.94
# MaxCAHA           2.11
# AvgCAHH           1.88
# AvgCAHA            2.0
# Name: 6, Length: 106, dtype: object
# Div                     E0
# Date            05/08/2022
# Time                 20:00
# HomeTeam    Crystal Palace
# AwayTeam           Arsenal
#                  ...
# PCAHA                 1.88
# MaxCAHH               2.09
# MaxCAHA               1.88
# AvgCAHH               2.03
# AvgCAHA               1.85
# Name: 0, Length: 106, dtype: object
